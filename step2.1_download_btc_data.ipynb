# %%
import yfinance as yf 
import pandas as pd

# %%
btc = yf.Ticker('BTC-USD')

# %%
# 10 year data 
df_btc = btc.history(period = '10y')

# %%
df_btc_2017_2026 = df_btc['2017-01-01':'2026-04-22']

# %%
df_btc_2017_2026.to_csv('btc_2017_2026.csv')
